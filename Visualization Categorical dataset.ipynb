# %% [markdown]
# # import necessary libraries

# %%
# !pip install xlrd
# Out:
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# Installing collected packages: xlrd
# Successfully installed xlrd-2.0.1
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\padma\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\padma\appdata\roaming\python\python39\site-packages)

# %%
import pandas as pd
import xlrd

# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\padma\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\padma\appdata\roaming\python\python39\site-packages)

# %% [markdown]
# # read the dataset

# %%
df=pd.ExcelFile("C:\\Users\\padma\\Downloads\\Task_for_internship\\Global-Superstore.xlsx")

# %%
df1=pd.read_excel(df)

# %%
df1.shape
# Out:
# (51290, 24)

# %%
df1.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
df1.dtypes
# Out:
# Row ID              int64
# Order ID           object
# Order Date         object
# Ship Date          object
# Ship Mode          object
# Customer ID        object
# Customer Name      object
# Segment            object
# City               object
# State              object
# Country            object
# Postal Code       float64
# Market             object
# Region             object
# Product ID         object
# Category           object
# Sub-Category       object
# Product Name       object
# Sales             float64
# Quantity            int64
# Discount          float64
# Profit            float64
# Shipping Cost     float64
# Order Priority     object
# dtype: object

# %%
import seaborn as sns

# %%
df=df1.loc[0:1000,:]

# %%
sns.catplot(x='Sales',y='Discount',data=df,palette='rainbow',alpha=1)
# Out:
# C:\Users\padma\AppData\Local\Temp\ipykernel_12900\816185589.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x='Sales',y='Discount',data=df,palette='rainbow',alpha=1)

# %%
sns.catplot(x='Sales',y='Discount',col='Category',data=df,palette='rainbow',alpha=1)
# Out:
# C:\Users\padma\AppData\Local\Temp\ipykernel_12900\547809291.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x='Sales',y='Discount',col='Category',data=df,palette='rainbow',alpha=1)

# %%
sns.lineplot(x='Discount',y='Sales',data=df,palette='rainbow',alpha=1)
# Out:
# C:\Users\padma\AppData\Local\Temp\ipykernel_12900\2820702551.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(x='Discount',y='Sales',data=df,palette='rainbow',alpha=1)
# <Axes: xlabel='Discount', ylabel='Sales'>

# %%
sns.lineplot(x='Discount',y='Profit',data=df)
# Out:
# <Axes: xlabel='Discount', ylabel='Profit'>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(50, 10))
sns.barplot(x='Sales',y='Profit',hue='Category',data=df)
# Out:
# <Axes: xlabel='Sales', ylabel='Profit'>

# %%
sns.catplot(x='Category',y='Profit',kind="box",data=df)

# %%
sns.catplot(x='Sub-Category',y='Sales',kind="violin",data=df)

# %%
sns.catplot(x='Ship Mode',kind="count",data=df)

# %%
sns.catplot(x='Ship Mode',y='Sales',kind="point",data=df)

# %%
sns.catplot(x='Category',y='Profit',kind="swarm",data=df)
# Out:
# C:\Users\padma\AppData\Roaming\Python\Python39\site-packages\seaborn\categorical.py:3399: UserWarning: 59.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\padma\AppData\Roaming\Python\Python39\site-packages\seaborn\categorical.py:3399: UserWarning: 52.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\padma\AppData\Roaming\Python\Python39\site-packages\seaborn\categorical.py:3399: UserWarning: 29.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\padma\AppData\Roaming\Python\Python39\site-packages\seaborn\categorical.py:3399: UserWarning: 69.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\padma\AppData\Roaming\Python\Python39\site-packages\seaborn\categorical.py:3399: UserWarning: 62.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\padma\AppData\Roaming\Python\Python39\site-packages\seaborn\categorical.py:3399: UserWarning: 44.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\padma\AppData\Roaming\Python\Python39\site-packages\seaborn\categorical.py:3399: UserWarning: 68.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\padma\AppData\Roaming\Python\Python39\site-packages\seaborn\categorical.py:3399: UserWarning: 62.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\padma\AppData\Roaming\Python\Python39\site-packages\seaborn\categorical.py:3399: UserWarning: 43.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\padma\AppData\Roaming\Python\Python39\site-packages\seaborn\categorical.py:3399: UserWarning: 43.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.barplot(x='Sales',y='Discount',hue='Category',data=df)
# Out:
# <Axes: xlabel='Sales', ylabel='Discount'>

# %%
sns.barplot(x='Sales',y='Profit',hue='Category',data=df)
# Out:
# <Axes: xlabel='Sales', ylabel='Profit'>

# %%
plt.figure(figsize=(25,20))
g=sns.barplot(x='Discount',y='Profit',hue='Category',data=df)

# %%
plt.figure(figsize=(25,20))
sns.barplot(x='Discount',y='Profit',hue='Market',data=df)
# Out:
# <Axes: xlabel='Discount', ylabel='Profit'>

# %%
df2=df.drop(['Row ID','Order ID'],axis=1)

# %%
sns.pairplot(data=df2)

# %%
plt.figure(figsize=(25,20))
sns.lineplot(x='Sales',y='Profit',hue='Country',data=df2)
# Out:
# <Axes: xlabel='Sales', ylabel='Profit'>

# %%
plt.figure(figsize=(25,20))
sns.lineplot(x='Sales',y='Discount',hue='Country',data=df2)
# Out:
# <Axes: xlabel='Sales', ylabel='Discount'>

# %%
sns.lmplot(x='Discount',y='Sales',data=df2,  fit_reg=False)

# %%
sns.lmplot(x='Discount',y='Profit',data=df2,  fit_reg=False)

# %%
import numpy as np
df3=df1[['Sales','Profit','Discount']]

# %%
plt.figure(figsize=(50, 30))
sns.heatmap(data=df3,cmap='coolwarm')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(x="Sales", y="Profit",
                      hue="Market",
                      data=df)
# Out:
# <Axes: xlabel='Sales', ylabel='Profit'>

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(x="Discount", y="Profit",
                      hue="Market",
                      data=df)
# Out:
# <Axes: xlabel='Discount', ylabel='Profit'>

# %%
sns.countplot(x='Market',data=df,palette='rainbow',alpha=0.8)
# Out:
# C:\Users\padma\AppData\Local\Temp\ipykernel_12900\499744861.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Market',data=df,palette='rainbow',alpha=0.8)
# <Axes: xlabel='Market', ylabel='count'>

# %%
sns.barplot(x='Market',y='Profit',data=df,palette='rainbow')
# Out:
# C:\Users\padma\AppData\Local\Temp\ipykernel_12900\3761408384.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Market',y='Profit',data=df,palette='rainbow')
# <Axes: xlabel='Market', ylabel='Profit'>

# %%
sns.boxplot(x='Market',y='Profit',data=df,palette='rainbow')
# Out:
# C:\Users\padma\AppData\Local\Temp\ipykernel_12900\144019278.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Market',y='Profit',data=df,palette='rainbow')
# <Axes: xlabel='Market', ylabel='Profit'>

# %%
df4=df[["Sales","Profit","Discount","Shipping Cost","Quantity"]]

# %%
df4_corr = df4.corr()

# %%
sns.heatmap(data=df4_corr,cmap="rainbow",annot=True)
# Out:
# <Axes: >
